# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Read the board_games.csv dataset
data = pd.read_csv("C:\\Users\\n\\Downloads\\board_games (1).csv")
data.head(5)
# Out:
#    game_id            name  max_players  playtime  min_age  min_players  \
# 0        1      Die Macher            5       240       14            3
# 1        2    Dragonmaster            4        30       12            3
# 2        3         Samurai            4        60       10            2
# 3        4  Tal der Könige            4        60       12            2
# 4        5         Acquire            6        90       12            3
#
#    age_of_game  users_rated   rating CardGame  ... WorldWarII Bluffing Humor  \
# 0           36         4498  7.66508       No  ...         No       No    No
# 1           41          478  6.60815      Yes  ...         No       No    No
# 2           24        12019  7.44119       No  ...         No       No    No
# 3           30          314  6.60675       No  ...         No       No    No
# 4           58        15195  7.35830       No  ...         No       No    No
#
# ...

# %%
#Question 1
from sklearn.preprocessing import LabelEncoder
board_games_data=data
# Separate the features (X) and the target variable (y)
X = board_games_data.drop(columns=["rating"])
y = board_games_data["rating"]

# Encode categorical variables
X_encoded = X.copy()
for column in X_encoded.columns:
    if X_encoded[column].dtype == object:
        X_encoded[column] = LabelEncoder().fit_transform(X_encoded[column])

X_all = X_encoded[predictors]
tree_all = DecisionTreeRegressor(random_state=0)
tree_all.fit(X_all, y)
# Calculate RMSE of tree_all
y_pred_all = tree_all.predict(X_all)
rmse_all = mean_squared_error(y, y_pred_all, squared=False)
print("The RMSE for all predictors are:",rmse_all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 14>()
#      11     if X_encoded[column].dtype == object:
#      12         X_encoded[column] = LabelEncoder().fit_transform(X_encoded[column])
# ---> 14 X_all = X_encoded[predictors]
#      15 tree_all = DecisionTreeRegressor(random_state=0)
#      16 tree_all.fit(X_all, y)
#
# NameError: name 'predictors' is not defined

# %%
#u677u9p7fghjol

# %%
# Encode categorical variables in the test dataset

X_test_encoded = X_test.copy()
for column in X_test_encoded.columns:
    if X_test_encoded[column].dtype == object:
        X_test_encoded[column] = LabelEncoder().fit_transform(X_test_encoded[column])

# Calculate RMSE for trees
y_pred_trees = tree_all.predict(X_test_encoded[predictors])
rmse_trees = np.sqrt(mean_squared_error(y_test, y_pred_trees))

y_pred_tree6 = tree6.predict(X_test_encoded[predictors])
rmse_tree6 = np.sqrt(mean_squared_error(y_test, y_pred_tree6))

y_pred_tree7 = tree7.predict(X_test_encoded[predictors])
rmse_tree7 = np.sqrt(mean_squared_error(y_test, y_pred_tree7))

y_pred_tree8 = tree8.predict(X_test_encoded[predictors])
rmse_tree8 = np.sqrt(mean_squared_error(y_test, y_pred_tree8))

y_pred_tree9 = tree9.predict(X_test_encoded[predictors])
rmse_tree9 = np.sqrt(mean_squared_error(y_test, y_pred_tree9))

# Compare RMSE values
lowest_rmse = min(rmse_tree6, rmse_tree7, rmse_tree8, rmse_tree9, rmse_trees)
if lowest_rmse == rmse_tree6:
    answer = "e) tree6"
elif lowest_rmse == rmse_tree7:
    answer = "d) tree7"
elif lowest_rmse == rmse_tree8:
    answer = "a) tree8"
elif lowest_rmse == rmse_tree9:
    answer = "b) tree9"
else:
    answer = "c) tree5"

answer

# %%
#Number 5
# Import necessary libraries
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate RMSE for trees
y_pred_trees = tree_all.predict(X_test_encoded[predictors])
rmse_trees = np.sqrt(mean_squared_error(y_test, y_pred_trees))

y_pred_tree6 = tree6.predict(X_test_encoded[predictors])
rmse_tree6 = np.sqrt(mean_squared_error(y_test, y_pred_tree6))

y_pred_tree7 = tree7.predict(X_test_encoded[predictors])
rmse_tree7 = np.sqrt(mean_squared_error(y_test, y_pred_tree7))

y_pred_tree8 = tree8.predict(X_test_encoded[predictors])
rmse_tree8 = np.sqrt(mean_squared_error(y_test, y_pred_tree8))

y_pred_tree9 = tree9.predict(X_test_encoded[predictors])
rmse_tree9 = np.sqrt(mean_squared_error(y_test, y_pred_tree9))

# Compare RMSE values
lowest_rmse = min(rmse_tree6, rmse_tree7, rmse_tree8, rmse_tree9, rmse_trees)
if lowest_rmse == rmse_tree6:
    answer = "e) tree6"
elif lowest_rmse == rmse_tree7:
    answer = "d) tree7"
elif lowest_rmse == rmse_tree8:
    answer = "c) tree5"
elif lowest_rmse == rmse_tree9:
    answer = "b) tree9"
else:
    answer = "a) tree8"

answer

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical variables in the training dataset
X_encoded = X.copy()
for column in X_encoded.columns:
    if X_encoded[column].dtype == object:
        X_encoded[column] = LabelEncoder().fit_transform(X_encoded[column])

# Encode categorical variables in the test dataset
X_test_encoded = X_test.copy()
for column in X_test_encoded.columns:
    if X_test_encoded[column].dtype == object:
        X_test_encoded[column] = LabelEncoder().fit_transform(X_test_encoded[column])

# Question 1
X_all = X_encoded[predictors]
tree_all = DecisionTreeRegressor(random_state=0)
tree_all.fit(X_all, y)

# Calculate RMSE of tree_all
y_pred_all = tree_all.predict(X_all)
rmse_all = mean_squared_error(y, y_pred_all, squared=False)

# Question 2
tree6 = DecisionTreeRegressor(random_state=0, ccp_alpha=0.005)
tree6.fit(X_all, y)
num_leaves_tree6 = tree6.get_n_leaves()

# Question 3
y_pred_tree6 = tree6.predict(X_all)
rmse_tree6 = mean_squared_error(y, y_pred_tree6, squared=False)

# Question 4
cp_values = [0.001, 0.0001, 0.1]
trees = []
rmses = []
for cp in cp_values:
    tree = DecisionTreeRegressor(random_state=0, ccp_alpha=cp)
    tree.fit(X_all, y)
    trees.append(tree)
    y_pred = tree.predict(X_all)
    rmse = mean_squared_error(y, y_pred, squared=False)
    rmses.append(rmse)

min_rmse_idx = np.argmin(rmses)
best_tree = trees[min_rmse_idx]
best_tree_rmse = rmses[min_rmse_idx]

# Question 5
y_pred_trees = tree_all.predict(X_test_encoded[predictors])
rmse_trees = mean_squared_error(y_test, y_pred_trees, squared=False)

y_pred_tree6 = tree6.predict(X_test_encoded[predictors])
rmse_tree6 = mean_squared_error(y_test, y_pred_tree6, squared=False)

y_pred_tree7 = trees[0].predict(X_test_encoded[predictors])
rmse_tree7 = mean_squared_error(y_test, y_pred_tree7, squared=False)

y_pred_tree8 = trees[1].predict(X_test_encoded[predictors])
rmse_tree8 = mean_squared_error(y_test, y_pred_tree8, squared=False)

y_pred_tree9 = trees[2].predict(X_test_encoded[predictors])
rmse_tree9 = mean_squared_error(y_test, y_pred_tree9, squared=False)
